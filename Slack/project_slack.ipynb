# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-данных:" data-toc-modified-id="Описание-данных:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание данных:</a></span><ul class="toc-item"><li><span><a href="#Импортируем-библиотеки" data-toc-modified-id="Импортируем-библиотеки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импортируем библиотеки</a></span></li><li><span><a href="#Загрузка-данных-в-датафрейм" data-toc-modified-id="Загрузка-данных-в-датафрейм-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузка данных в датафрейм</a></span></li><li><span><a href="#Общая-информация-о-полученном-датафрейме" data-toc-modified-id="Общая-информация-о-полученном-датафрейме-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Общая информация о полученном датафрейме</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Исправим-даты:" data-toc-modified-id="Исправим-даты:-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Исправим даты:</a></span></li><li><span><a href="#Добавление-дополнительных-столбцов" data-toc-modified-id="Добавление-дополнительных-столбцов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Добавление дополнительных столбцов</a></span></li><li><span><a href="#Неявные-дубликаты" data-toc-modified-id="Неявные-дубликаты-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Неявные дубликаты</a></span></li><li><span><a href="#Пропуски" data-toc-modified-id="Пропуски-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Пропуски</a></span><ul class="toc-item"><li><span><a href="#Пропуски-в-client_msg_id" data-toc-modified-id="Пропуски-в-client_msg_id-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Пропуски в <code>client_msg_id</code></a></span></li><li><span><a href="#Пропуски-в-subtype" data-toc-modified-id="Пропуски-в-subtype-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Пропуски в <code>subtype</code></a></span></li><li><span><a href="#Пропуски-в-latest_reply" data-toc-modified-id="Пропуски-в-latest_reply-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Пропуски в <code>latest_reply</code></a></span></li><li><span><a href="#Пропуски-в--team" data-toc-modified-id="Пропуски-в--team-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Пропуски в  <code>team</code></a></span></li><li><span><a href="#Пропуски-в-thread_ts" data-toc-modified-id="Пропуски-в-thread_ts-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>Пропуски в <code>thread_ts</code></a></span></li><li><span><a href="#Пропуски-в-user" data-toc-modified-id="Пропуски-в-user-2.4.6"><span class="toc-item-num">2.4.6&nbsp;&nbsp;</span>Пропуски в <code>user</code></a></span></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Сообщения." data-toc-modified-id="Сообщения.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Сообщения.</a></span></li><li><span><a href="#Реакции" data-toc-modified-id="Реакции-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Реакции</a></span></li><li><span><a href="#Лучший-Пользователь" data-toc-modified-id="Лучший-Пользователь-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Лучший Пользователь</a></span></li><li><span><a href="#Приток-и-отток-пользователей" data-toc-modified-id="Приток-и-отток-пользователей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Приток и отток пользователей</a></span></li></ul></li><li><span><a href="#Общий-вывод:" data-toc-modified-id="Общий-вывод:-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Общий вывод:</a></span></li></ul></div>

# %% [markdown]
# # Чат "Слак"

# %% [markdown]
# ***Для анализа предлагаются данные о сообщениях студентов Яндекс Практикума в чатах.***
# # Цель проекта:
# Проанализировать активность в чатах Слак.
# # Проблема:
# Низкая обратная связь на важные посты, публикуемые в чатах
# # Задачи:
# - проанализировать поведение студентов в чатах;
# - выявить паттерны, динамику, цикличность в течение дня, недели, месяца, года;
# - визуализировать свои находки;
# - помочь нам понять, когда активность в чатах наибольшая, и когда лучше публиковать посты/анонсы, чтобы получить больше откликов;
# - проанализировать различные типы каналов, когорт, групп;
# - оценить в каких общения больше, в каких меньше, и как они различаются от когорты к когорте,
# от канала к каналу.
# - По возможности сделать дополнительные наблюдения.
# - Сделать выводы, дать рекомендации.
#
# Исходные данные расположены в открытом доступе.
# Ссылка на датасет: https://disk.yandex.ru/d/or1EH_nJ0413gQ

# %% [markdown]
# ## Описание данных:
# - `Unnamed`: 0 - индекс (можно удалить)
# - `client_msg_id` - id сообщения
# - `type` - тип поста
# - `user` - id пользователя
# - `ts` - дата поста
# - `thread_ts` - дата треда
# - `latest_reply` - дата ответа
# - `team` - факт вхождения в неизвестную группу (?)
# - `subtype` - метка действий пользователя
# - `channel` - канал
# - `file_date` - дата файла
# - `attachments` - прикреплённые файлы
# - `reactions` - реакции
# - `text_len` - длина текста сообщения
# - `text_words` - количество слов в сообщении

# %% [markdown]
# ### Импортируем библиотеки

# %%
import pandas as pd
import numpy as np
import sys
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns
import os
import requests
from io import StringIO
from urllib.parse import urlencode
import json
import ast
import re

# %% [markdown]
# ### Загрузка данных в датафрейм

# %% [markdown]
# Определяем путь загрузки данных

# %%
pth1 = r'D:\bigData\chat_data_clean.csv' # для работы в офлайн режиме необходимо скачать файл
pth2 =r'C:\Users\user\Documents\chat_data_clean.csv'

# %%
if os.path.exists(pth1):
    data = pd.read_csv(pth1)
elif os.path.exists(pth2):
    data = pd.read_csv(pth2)
else:
    print('что то пошло не так...')

# %% [markdown]
# ### Общая информация о полученном датафрейме

# %%
pd.set_option('display.max_rows', None)  # вывод с максимальным размером строк
pd.options.mode.chained_assignment = None

# %%
#код ревьюера
pd.set_option('display.max_columns', None)

# %%
display(data.head()) # общий вид дф
# Out:
#    Unnamed: 0                         client_msg_id     type         user  \
# 0           0  ae31e785-257b-4290-a4c6-9721337f67ea  message  U03JYMWQLP5
# 1           1  7f644ae8-16d4-4c9e-9c4f-8b2d6df6a28d  message  U03V483FRKM
# 2           2                                   NaN  message  U02KVQJHQ5S
# 3           3  6c5bf2c1-8579-413c-8e8f-ec3a0e3698a8  message  U03JYMWQLP5
# 4           4  b5e3413b-8f04-4192-948b-2423eb3192b2  message  U040E2D6CF2
#
#              ts  latest_reply       team     thread_ts       subtype  \
# 0  1.669643e+09  1.669645e+09  TPV9DP0N4  1.669643e+09           NaN
# 1  1.669645e+09           NaN  TPV9DP0N4  1.669643e+09           NaN
# 2  1.669647e+09           NaN        NaN           NaN  channel_join
# 3  1.669709e+09  1.669719e+09        NaN  1.669709e+09           NaN
# 4  1.669711e+09           NaN  TPV9DP0N4  1.669709e+09           NaN
#
#              channel   file_date  attachments  \
# 0  data-analysts-bus  2022-11-28            0
# ...

# %% [markdown]
# Наглядно видно, что присутствуют пропуски и некоторые даты отображаются некорректно.

# %%
display(data.info()) # информация о дф
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26533 entries, 0 to 26532
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     26533 non-null  int64
#  1   client_msg_id  18262 non-null  object
#  2   type           26533 non-null  object
#  3   user           23643 non-null  object
#  4   ts             26533 non-null  float64
#  5   latest_reply   2303 non-null   float64
#  6   team           15857 non-null  object
#  7   thread_ts      18222 non-null  float64
#  8   subtype        8317 non-null   object
#  9   channel        26533 non-null  object
#  10  file_date      26533 non-null  object
#  11  attachments    26533 non-null  int64
#  12  reactions      4169 non-null   object
#  13  text_len       26533 non-null  int64
#  14  text_words     26533 non-null  int64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 3.0+ MB
# None

# %% [markdown]
# Типы данных даты не соответствуют описанию. Необходимы замены в ts, latest_reply,thread_ts, file_date.
#
# Пропуски в % соотношении от общего объема строк в столбце.

# %%
round(data.isna().sum()/len(data)*100, 2) # процент пропусков в каждом столбце
# Out:
# Unnamed: 0        0.00
# client_msg_id    31.17
# type              0.00
# user             10.89
# ts                0.00
# latest_reply     91.32
# team             40.24
# thread_ts        31.32
# subtype          68.65
# channel           0.00
# file_date         0.00
# attachments       0.00
# reactions        84.29
# text_len          0.00
# text_words        0.00
# dtype: float64

# %% [markdown]
# Нагляднее можно посмотреть на тепловой карте.

# %%
cols = data.columns[:15] # выводим 15 колонок
# определяем цвета
# зеленый - пропущенные данные, черный - не пропущенные
colours = ['#000000', '#85ff85']
sns.heatmap(data[cols].isnull(), cmap=sns.color_palette(colours));

# %% [markdown]
# По процентам пропуска можно увидеть, что более 91% отсутствуют ответы на сообщения, 84% пропусков в столбце реакции.

# %% [markdown]
# ## Предобработка данных
#
# Столбец Unnamed неинформативный. Удалим за ненадобностью. Данный столбце дублирует индекс. Возможно он появился при выгрузки данных ранее.

# %%
data = data.drop('Unnamed: 0', axis =1)
data.head()
# Out:
#                           client_msg_id     type         user            ts  \
# 0  ae31e785-257b-4290-a4c6-9721337f67ea  message  U03JYMWQLP5  1.669643e+09
# 1  7f644ae8-16d4-4c9e-9c4f-8b2d6df6a28d  message  U03V483FRKM  1.669645e+09
# 2                                   NaN  message  U02KVQJHQ5S  1.669647e+09
# 3  6c5bf2c1-8579-413c-8e8f-ec3a0e3698a8  message  U03JYMWQLP5  1.669709e+09
# 4  b5e3413b-8f04-4192-948b-2423eb3192b2  message  U040E2D6CF2  1.669711e+09
#
#    latest_reply       team     thread_ts       subtype            channel  \
# 0  1.669645e+09  TPV9DP0N4  1.669643e+09           NaN  data-analysts-bus
# 1           NaN  TPV9DP0N4  1.669643e+09           NaN  data-analysts-bus
# 2           NaN        NaN           NaN  channel_join  data-analysts-bus
# 3  1.669719e+09        NaN  1.669709e+09           NaN  data-analysts-bus
# 4           NaN  TPV9DP0N4  1.669709e+09           NaN  data-analysts-bus
#
# ...

# %% [markdown]
# ### Исправим даты:

# %%
def to_date(column): # для упрощения создадим функцию.
    data[column] = pd.to_datetime(data[column], unit='s').astype('datetime64[s]') # так же поменяем тип даты с object на datetime64
    data[column] = data[column].dt.round('1s') # округляем дату до секунд

# %%
to_date('ts')
to_date('latest_reply')
to_date('thread_ts')

# %% [markdown]
# Поменяем тип у столбца file_date

# %%
data['file_date']=data['file_date'].astype('datetime64[s]')
display(data.head())
# Out:
#                           client_msg_id     type         user  \
# 0  ae31e785-257b-4290-a4c6-9721337f67ea  message  U03JYMWQLP5
# 1  7f644ae8-16d4-4c9e-9c4f-8b2d6df6a28d  message  U03V483FRKM
# 2                                   NaN  message  U02KVQJHQ5S
# 3  6c5bf2c1-8579-413c-8e8f-ec3a0e3698a8  message  U03JYMWQLP5
# 4  b5e3413b-8f04-4192-948b-2423eb3192b2  message  U040E2D6CF2
#
#                    ts        latest_reply       team           thread_ts  \
# 0 2022-11-28 13:49:23 2022-11-28 14:24:08  TPV9DP0N4 2022-11-28 13:49:23
# 1 2022-11-28 14:24:08                 NaT  TPV9DP0N4 2022-11-28 13:49:23
# 2 2022-11-28 14:48:50                 NaT        NaN                 NaT
# 3 2022-11-29 08:08:12 2022-11-29 10:56:57        NaN 2022-11-29 08:08:12
# 4 2022-11-29 08:32:32                 NaT  TPV9DP0N4 2022-11-29 08:08:12
#
#         subtype            channel  file_date  attachments  \
# 0           NaN  data-analysts-bus 2022-11-28            0
# ...

# %% [markdown]
# Теперь можно определить временной диапазон полученных данных.

# %%
def renge_time (times):
    min_time = data[times].min()
    max_time = data[times].max()
    print(f'начальное время полученных данных -', min_time)
    print(f'последнее время полученных данных -', max_time)
    print(f'общее время -', max_time - min_time)

# %%
renge_time('ts')
# Out:
# начальное время полученных данных - 2022-10-21 09:00:00
# последнее время полученных данных - 2023-02-09 11:02:03
# общее время - 111 days 02:02:03

# %% [markdown]
# Рассмотрим временные диапазоны колонок `thread_ts` и `file_date` и их распределение по диапазону `ts`

# %%
renge_time('thread_ts')
renge_time('file_date')
# Out:
# начальное время полученных данных - 2022-10-21 09:00:00
# последнее время полученных данных - 2022-12-16 19:05:31
# общее время - 56 days 10:05:31
# начальное время полученных данных - 2022-10-21 00:00:00
# последнее время полученных данных - 2023-02-09 00:00:00
# общее время - 111 days 00:00:00

# %% [markdown]
# Оказалось, что диапазон даты тредов в два раза меньше, чем диапазон даты постов и охватывают только половину рассмотренного периода.
# С диапазоном дат загрузки файлов все более тривиально - полностью совпадает с диапазоном дат постов.

# %% [markdown]
# ### Добавление дополнительных столбцов
# Столбец `reactions` выглядит не информативно, разобьем его на 3: names, users, counts и посчитаем общее число реакций

# %%
# Функция для разбора столбца 'reactions'
def drop_reactions(reaction_str):
    try:
        return ast.literal_eval(reaction_str)
    except (ValueError, SyntaxError):
        return []

# %%
# Применяем функцию для преобразования столбца 'reactions'
data['reactions'] = data['reactions'].apply(drop_reactions)

# %%
# Создаем новые столбцы для данных из столбца 'reactions'
data['r_names'] = data['reactions'].apply(lambda reactions: ', ' \
    .join([reaction['name'] for reaction in reactions]) if reactions else '')
data['r_users'] = data['reactions'].apply(lambda reactions: ', ' \
    .join([', '.join(reaction['users']) for reaction in reactions]) if reactions else '')
data['r_counts'] = data['reactions'].apply(lambda reactions: '' \
    .join([str(reaction['count']) for reaction in reactions]) if reactions else '')

# %% [markdown]
# Создадим функцию для подсчета количества реакций

# %%
data['r_counts']
# Out:
# 0
# 1                                                    1
# 2
# 3                                                    1
# 4
# 5
# 6
# 7                                                  221
# 8
# 9                                                    1
# 10
# 11
# 12
# 13
# 14                                                   1
# 15
# 16                                                   1
# 17                                                   1
# 18                                                   2
# 19
# 20
# 21
# 22
# 23                                                   1
# 24
# 25
# 26
# 27                                                   1
# 28
# 29                                                   1
# 30
# 31                                                   1
# 32                                                   1
# 33                                                   1
# 34                                                   1
# 35
# ...

# %%
def lens(df: pd.DataFrame, col: str):
    for i in range(len(df[col])):
        df[col][i] = sum(map(int, df[col][i]))

# %% [markdown]
# Подсчитаем количество реакций.

# %%
lens(data,'r_counts')
data['r_counts']
# Out:
# 0          0
# 1          1
# 2          0
# 3          1
# 4          0
# 5          0
# 6          0
# 7          5
# 8          0
# 9          1
# 10         0
# 11         0
# 12         0
# 13         0
# 14         1
# 15         0
# 16         1
# 17         1
# 18         2
# 19         0
# 20         0
# 21         0
# 22         0
# 23         1
# 24         0
# 25         0
# 26         0
# 27         1
# 28         0
# 29         1
# 30         0
# 31         1
# 32         1
# 33         1
# 34         1
# 35         0
# 36         1
# 37         1
# 38         3
# 39         1
# 40         0
# 41         1
# 42         0
# 43         0
# 44         1
# 45         2
# 46         1
# 47         1
# 48         1
# 49         1
# 50         0
# 51         0
# 52         2
# 53         0
# 54         1
# 55         1
# 56         3
# 57         0
# 58         1
# 59         2
# 60         1
# 61         1
# 62         0
# 63         1
# 64         0
# 65         1
# ...

# %%
data['r_counts']= data['r_counts'].astype(int)

# %% [markdown]
# Столбец `reactions` больше не нужен, удалим.
# Разобьем даты на дни недели, месяцы, года и часы. Эти столбы понадобятся при анализе.

# %%
data.drop(columns=['reactions'], inplace=True)

# %%
data['ts']=pd.to_datetime(data['ts'])
data['ts_w']=data['ts'].dt.weekday #создаю столбец с днем недели
data['ts_mnth']=data['ts'].dt.month #создаю столбец с месяцем
data['ts_y']=data['ts'].dt.year #создаю столбец с годом
data['ts_h'] = data['ts'].dt.hour #создаю столбец час

# %%
#код ревьюера
data.sample(10)
# Out:
#                               client_msg_id     type         user  \
# 16690                                   NaN  message          NaN
# 14376  f6dfee61-f0b8-4cae-8537-94947214c004  message  U03HWJ20B9T
# 24139  eb510ed5-b8df-439f-8b81-3e02e7fca191  message  U02PLR8QYT0
# 18474  6cae88ca-dc2a-4d08-bc9c-a26db0dd054d  message  U03GSK9MPML
# 26175                                   NaN  message  U03RGG6CDSQ
# 3127                                    NaN  message  U02KVQJHQ5S
# 25281  5000c601-7d85-4389-a2f6-0460a6013a93  message  U03A3EWK561
# 8916                                    NaN  message  U043ZSXJNDD
# 4715   941472b3-74f4-43e4-a133-1fd2a9f512ab  message  U042M8Z02G4
# 25124  7b3b6745-0110-4c88-b0a0-5c75714af794  message  U02L86XR31D
#
#                        ts        latest_reply       team           thread_ts  \
# 16690 2022-11-28 07:00:37                 NaT        NaN                 NaT
# 14376 2022-11-29 14:28:30                 NaT  TPV9DP0N4 2022-11-28 19:02:15
# ...

# %% [markdown]
# Создадим сгруппированный столбец каналов по профессиям

# %%
data['profession']=data['channel']
def professions (df: pd.DataFrame, col: str):
    for i in range(len(df[col])):
        if df[col][i][0:4]=='data' :
            df['profession'][i] = df[col][i][0:4]
        elif df[col][i][0:11]== 'masterskaya':
                df['profession'][i] = df[col][i][0:11]
        elif df[col][i][0:3]=='sql':
                df['profession'][i] = df[col][i][0:3]
        elif df[col][i][0:11]== 'donorsearch':
                df['profession'][i] = df[col][i][0:11]
        else:
                df['profession'][i] = df[col][i][0:2]
professions(data,'profession')

# %%
data['profession'].unique()
# Out:
# array(['data', 'da', 'de', 'dl', 'donorsearch', 'ds', 'masterskaya',
#        'sql'], dtype=object)

# %% [markdown]
# ### Неявные дубликаты
# Наглядно рассмотрим наличие дубликатов

# %%
def uniq (colums):  
    uni = data[colums].unique()
    print(len(uni),' уникальных значений в столбце', colums) # выведет количество уникальных значений
    uni = len(uni) / len(data[colums])
    print(round(1-uni,3)*100, '% от общего числа строк') # выведет % от общего числа строк

# %%
uniq('client_msg_id')
# Out:
# 18263  уникальных значений в столбце client_msg_id
# 31.2 % от общего числа строк

# %%
uniq('type')
data['type'].unique()
# Out:
# 1  уникальных значений в столбце type
# 100.0 % от общего числа строк
# array(['message'], dtype=object)

# %%
uniq('latest_reply')
# Out:
# 2301  уникальных значений в столбце latest_reply
# 91.3 % от общего числа строк

# %%
uniq('team')
data['team'].unique()
# Out:
# 2  уникальных значений в столбце team
# 100.0 % от общего числа строк
# array(['TPV9DP0N4', nan], dtype=object)

# %%
uniq('subtype')
# Out:
# 10  уникальных значений в столбце subtype
# 100.0 % от общего числа строк

# %%
uniq('channel')
# Out:
# 571  уникальных значений в столбце channel
# 97.8 % от общего числа строк

# %% [markdown]
# Нельзя сказать, что данные каналы дублируются, возможно они специально созданы из за ограничения количества пользователей в канале, но обьединив их мы не исказим общую картину.

# %%
print('Всего уникальных: ', len(data['channel'].unique()))
# Out:
# Всего уникальных:  571

# %%
def jr_replace(x):
    match = re.sub(r'_1$|_2$|_3$|_blue$|_red$|_yellow$|_green$|_01$|_02$|_03$|_orange$|_purple$|_new$|_me$',"",x)
    return match
data['channel'] = data['channel'].apply(jr_replace)
len(data['channel'].unique())
print('Всего уникальных: ', len(data['channel'].unique()))
# Out:
# Всего уникальных:  492

# %% [markdown]
# После преобразования мы сократили всего 79 каналов.

# %% [markdown]
# Создадим стобец темы каналов

# %%
data['cohorts']=data['channel']

# %%
def cohort (df: pd.DataFrame, col: str):
    for i in range(len(df[col])):
        df[col][i] = re.split("_|-",df[col][i])
        a =df[col][i]
        try:
            if df[col][i][0]=='data' :
                df[col][i] = a[-2]
            elif df[col][i][0]=='masterskaya':
                df[col][i] = a[0]
            else:
                df[col][i] = a[-1]
        except:
            df[col][i] = df[col][i]

cohort(data,'cohorts')
data['cohorts']=data['cohorts']
for i in range(len(data['cohorts'])):
    data['cohorts'][i] = ''.join(data['cohorts'][i])

# %%
data['cohorts'].unique()
# Out:
# array(['analysts', 'logs', 'data', 'edteam', 'exerciser', 'projects',
#        'info', 'library', 'teamwork', 'digitalprof', 'профессии',
#        'project', 'b2g', 'mentors', 'apps', 'telecom', 'study', 'kt',
#        'pro1', 'pro2', 'pro3', 'pro4', 'plus', 'community', 'group',
#        'tutorial', 'problem', 'topic1', 'topic2', 'topic3', 'professions',
#        'project1', 'coffee', 'feedback', 'teach', 'academ', 'donorsearch',
#        'masterskaya'], dtype=object)

# %%
data['attachments'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
data['r_names'].unique()
# Out:
# array(['', 'pray', 'cat-high-five',
#        'cat-high-five, hihello, orange_heart', 'cool-doge',
#        'woman-running', 'orange_heart', '+1', 'eyes, gratitude-thank-you',
#        'green_tick2', 'cat-high-five, gratitude-spasibo',
#        'gratitude-spasibo', 'pray, bear_hug', 'cat-high-five, 100',
#        'eyes, green_tick2', '100', 'bear_hug', 'blush', 'muscle', 'eyes',
#        'eyes, +1, writing_hand, notion', 'ok_hand', 'fingerguns',
#        '+1, gratitude-spasibo', 'white_check_mark', 'heart', 'eyes, -1',
#        '02heart', '+1::skin-tone-2', 'done, +1',
#        'done, gratitude-spasibo', 'done', 'done, orange_heart',
#        'gift, clinking_glasses, mx_claus, magic, snowflake, mx_claus::skin-tone-3',
#        'partying_face, the_horns',
#        'tada, happy2, clinking_glasses, christmas_tree, snowman',
#        'green_heart', 'orange_heart, green_heart', 'catshake, caree',
#        'doge_hug, cat-tilted, bear_hug', 'happy-cat, green_heart', 'fire',
# ...

# %% [markdown]
# Остальные столбцы не нуждаются в преобразовании и исключению дубликатов.

# %% [markdown]
# ### Пропуски
#
# Проверим взаимосвязь пропусков.
#
# #### Пропуски в `client_msg_id`

# %%
display(data[data['client_msg_id'].isna()].head(15))
# Out:
#     client_msg_id     type         user                  ts  \
# 2             NaN  message  U02KVQJHQ5S 2022-11-28 14:48:50
# 5             NaN  message  U0421JZP400 2022-11-29 10:19:47
# 6             NaN  message  U02Q4P6SGBC 2022-11-29 10:19:47
# 97            NaN  message    USLACKBOT 2022-12-16 09:38:19
# 197           NaN  message  U01QMDLG9AP 2022-12-13 14:06:03
# 206           NaN  message  U02BSPH6S5P 2022-12-21 09:27:53
# 207           NaN  message  U02PLR8QYT0 2022-12-19 16:55:57
# 208           NaN  message  U0303APE8P8 2022-12-19 16:56:07
# 209           NaN  message  U02PLR8QYT0 2022-12-19 16:56:23
# 210           NaN  message  U0303APE8P8 2022-12-19 16:56:31
# 211           NaN  message  U02PLR8QYT0 2022-12-19 16:57:02
# 212           NaN  message  U0303APE8P8 2022-12-19 16:57:15
# 213           NaN  message  U02PLR8QYT0 2022-12-19 16:57:33
# 214           NaN  message  U0303APE8P8 2022-12-19 16:57:42
# 215           NaN  message  U03263SP49E 2022-11-28 06:44:38
#
# ...

# %% [markdown]
# В основном пропуски в столбцах не считаются ошибкой,а являются техническим пропуском, который обьясняется столбцом `subtype`.
# В строке столбца `subtype`, где пропуск в столбце `client_msg_id`, расположена запись `channel_join`, `bot_remove`, `channel_unarchive`,  `channel_leave` и т.д..
#
# #### Пропуски в `subtype`

# %%
display(data[data['subtype'].isna()].head())
# Out:
#                           client_msg_id     type         user  \
# 0  ae31e785-257b-4290-a4c6-9721337f67ea  message  U03JYMWQLP5
# 1  7f644ae8-16d4-4c9e-9c4f-8b2d6df6a28d  message  U03V483FRKM
# 3  6c5bf2c1-8579-413c-8e8f-ec3a0e3698a8  message  U03JYMWQLP5
# 4  b5e3413b-8f04-4192-948b-2423eb3192b2  message  U040E2D6CF2
# 7  6a730fa5-7934-41f4-96f0-aa04787bce8e  message  U03DZHHUACW
#
#                    ts        latest_reply       team           thread_ts  \
# 0 2022-11-28 13:49:23 2022-11-28 14:24:08  TPV9DP0N4 2022-11-28 13:49:23
# 1 2022-11-28 14:24:08                 NaT  TPV9DP0N4 2022-11-28 13:49:23
# 3 2022-11-29 08:08:12 2022-11-29 10:56:57        NaN 2022-11-29 08:08:12
# 4 2022-11-29 08:32:32                 NaT  TPV9DP0N4 2022-11-29 08:08:12
# 7 2022-11-29 10:26:46 2022-11-29 12:08:01  TPV9DP0N4 2022-11-29 10:26:46
#
#   subtype            channel  file_date  attachments  text_len  text_words  \
# ...

# %% [markdown]
# По уникальным значениям столбца `subtype` видно, что это технический столбец, в котором указаны действия пользователей, а пропуски - публикация поста пользователем. Заменим пропуски на значение `post_message`.

# %%
rows = (data['client_msg_id'] !=0) & (data['subtype'].isna())
data.loc[rows, "subtype"] = "post_message"

# %%
data['subtype'].unique()
# Out:
# array(['post_message', 'channel_join', 'bot_remove', 'thread_broadcast',
#        'channel_unarchive', 'channel_leave', 'bot_message',
#        'channel_purpose', 'tombstone', 'channel_name'], dtype=object)

# %% [markdown]
# Основные моменты обработаны, можно приступать к анализу

# %%
#код ревьюера
(
    (data
     .isna().mean() *100)
    .to_frame()
    .rename(columns = {0: 'missing_values'})
    .query('missing_values > 0')
    .sort_values(by = 'missing_values', ascending = False)
    .style.background_gradient('Greens').format(precision=2)
)
# Out:
# <style type="text/css">
# #T_79d18_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_79d18_row1_col0 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_79d18_row2_col0 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_79d18_row3_col0 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_79d18_row4_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_79d18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79d18_level0_col0" class="col_heading level0 col0" >missing_values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79d18_level0_row0" class="row_heading level0 row0" >latest_reply</th>
#       <td id="T_79d18_row0_col0" class="data row0 col0" >91.32</td>
#     </tr>
#     <tr>
#       <th id="T_79d18_level0_row1" class="row_heading level0 row1" >team</th>
#       <td id="T_79d18_row1_col0" class="data row1 col0" >40.24</td>
#     </tr>
# ...

# %% [markdown]
# #### Пропуски в `latest_reply`

# %%
display(data[data['latest_reply'].isna()].sample(10))
# Out:
#                               client_msg_id     type         user  \
# 21803  fe02a6a0-2f69-439e-b6bb-2cdf0da2fde4  message  U03F5HNG351
# 6895   2b74aec2-31a7-4c54-b984-909c460cec34  message  U0447UAVBGW
# 21811  8d75a705-c793-4ae6-8d54-558fe06f11fb  message  U040RAZ99HA
# 25053  D931F632-C579-49E8-B2E2-6E61863867A0  message  U03AWRD3UE5
# 13610  265a4a90-26f1-4f6e-8b55-71e9fa1a03c3  message  U037V4NE7FT
# 9106   390dae67-92f1-4522-9878-3492d4d98b70  message  U048CBEDK7V
# 13675                                   NaN  message  U03PAQ6NLS2
# 26240  3b6dab94-9aeb-4616-9d83-751783a419f5  message  U018VDC3U00
# 13707  9AA078D7-1E0B-4F29-B539-CE9B3DA52E42  message  U0401TL94AZ
# 10435  046eba02-3a9a-421d-a481-7e33f4c49bb7  message  U0179RY000Y
#
#                        ts latest_reply       team           thread_ts  \
# 21803 2022-12-08 12:50:26          NaT  TPV9DP0N4 2022-11-28 07:00:13
# 6895  2022-12-08 19:21:13          NaT  TPV9DP0N4 2022-11-28 07:00:54
# ...

# %% [markdown]
# На первый взгляд можно сказать, что есть взаимосвязь пропусков столбца `latest_reply` и технического столбца `subtype`.
# Рассмотрим строки при условии уникальных значений столбца `subtype` тех, при которых есть значения.

# %%
nnull = data[(data['latest_reply'].notna())] # проверим на наличие записей в строках и запишем в df.
nnull['subtype'].unique() # выводим уникальные значения столбца subtype.
# Out:
# array(['post_message', 'bot_message', 'tombstone'], dtype=object)

# %% [markdown]
# Проверим условие пропусков в столбцах, где можно проследить взаимосвязь.

# %%
display(data[(data['latest_reply'].isna()) & (data['subtype'] == 'post_message')].sample(10))
# Out:
#                               client_msg_id     type         user  \
# 12072  83988d2c-c6f9-4b7d-b0bf-095fd63a0a10  message  U040N3MUT0S
# 6912   f4e8296c-3c15-4a59-96c4-d231c50c9a08  message  U0447UAVBGW
# 25593  6eee1063-7d0b-4a9f-afa9-080507e03e43  message  U03HSPGJ7JA
# 10382  facb459d-9b70-42fa-a50a-71bc9d281b21  message  U0179RY000Y
# 15848  EEAF339B-3327-4C29-B8F6-5E46ED9527FD  message  U043FGY0T9V
# 17142  388eb42c-563d-408e-94cb-a57fecc5ab02  message  U03GWESC34N
# 14677  9E072866-C3D4-4DBE-A248-809E85059F56  message  U046CH4H3AN
# 24269  68d08f73-6f4e-4a38-9306-ecc818a79f1b  message  U04BFBKAR9S
# 15437  83b56e73-617f-4c7c-9c0c-14dcd3061017  message  U02QN4YHZ7S
# 18428  a01724fb-826c-4335-8565-307cc7ba0eca  message  U03JV2AKE2Z
#
#                        ts latest_reply       team           thread_ts  \
# 12072 2022-12-04 21:13:22          NaT  TPV9DP0N4 2022-11-28 07:00:48
# 6912  2022-12-11 08:13:08          NaT        NaN 2022-11-28 07:00:53
# ...

# %% [markdown]
# Возможно пропуски появились при отсутствии ответов на сообщения пользователей. При данном условии невозможно заполнить пропуски.

# %%
display(data[(data['subtype'] == 'bot_message')].sample(10))
# Out:
#       client_msg_id     type user                  ts        latest_reply  \
# 22783           NaN  message  NaN 2022-11-28 07:01:10 2022-11-30 10:04:04
# 11503           NaN  message  NaN 2022-11-28 07:00:33                 NaT
# 691             NaN  message  NaN 2022-11-28 07:00:25 2022-11-30 12:38:37
# 21412           NaN  message  NaN 2022-11-28 07:00:24                 NaT
# 24000           NaN  message  NaN 2022-12-02 14:00:56                 NaT
# 1272            NaN  message  NaN 2022-12-06 11:30:13                 NaT
# 687             NaN  message  NaN 2022-11-28 07:00:22                 NaT
# 10266           NaN  message  NaN 2022-11-28 07:00:28 2022-12-13 11:52:53
# 18511           NaN  message  NaN 2022-11-28 12:00:45 2022-12-15 23:52:30
# 3208            NaN  message  NaN 2022-12-05 07:00:51 2022-12-05 15:53:17
#
#       team           thread_ts      subtype               channel  file_date  \
# ...

# %% [markdown]
# При данном условии заполнить пропуски невозможно. Закономерности не выявлено.

# %%
display(data[(data['latest_reply'].isna()) & (data['subtype'] == 'tombstone')])
# Out:
# Empty DataFrame
# Columns: [client_msg_id, type, user, ts, latest_reply, team, thread_ts, subtype, channel, file_date, attachments, text_len, text_words, r_names, r_users, r_counts, ts_w, ts_mnth, ts_y, ts_h, profession, cohorts]
# Index: []

# %% [markdown]
# При данном условии пропусков в колонке latest_reply нет.

# %% [markdown]
# Взаимосвязи с остальными столбцами искать нецелесообразно из за отсутсвия данных.
# Из вышеуказаного следует, что пропуски в столбце `latest_reply` заполнить невозможно.
#
# #### Пропуски в  `team`

# %%
print(data['team'].isna().sum())
# Out:
# 10676

# %%
data.sample(10)
# Out:
#                               client_msg_id     type         user  \
# 975                                     NaN  message  U03C7ALCXH6
# 9187   1a137ba1-c77b-463b-9c3b-26e0a095a487  message  U048ESH8N3E
# 3050   4947D471-FB7A-44A6-9DEC-CC1125B0A889  message  U03T1HD1DG8
# 1346   16867fa9-c8ee-4c9c-a8b5-36e1c9a81f19  message  U031KRDGHEG
# 22417  8b672c19-26a8-417d-a796-6a0c82bf6ee0  message  U0491MRCUJC
# 22851  fcadd418-5703-4230-8e5e-d74cd3246132  message  U04A5DWBD70
# 8617                                    NaN  message  U042XECC6MP
# 22687  1fca2c13-279d-4ccf-a5af-671439b3223e  message  U0125S9UD16
# 15060                                   NaN  message  U03Q7QEFK9P
# 3946   f785224e-8e9c-478a-9e8b-46062b4ab27a  message  U042M4TNF44
#
#                        ts latest_reply       team           thread_ts  \
# 975   2022-11-27 17:52:13          NaT        NaN                 NaT
# 9187  2022-12-06 17:06:18          NaT  TPV9DP0N4 2022-12-05 07:00:02
# ...

# %%
data['team'].unique()
# Out:
# array(['TPV9DP0N4', nan], dtype=object)

# %% [markdown]
# очевидно, что TPV9DP0N4 - единственное значение, при котором пишут сообщения пользователи и пропуски являются ошибочным значением. Заменим пропуск на TPV9DP0N4.

# %%
rows = ((data['subtype'] == 'post_message') & (data['team'].isna()))
data.loc[rows, "team"] = "TPV9DP0N4"
print('Уменьшили число пропусков на ', 10676-data['team'].isna().sum())
# Out:
# Уменьшили число пропусков на  2451

# %% [markdown]
# #### Пропуски в `thread_ts`

# %%
display(data[data['thread_ts'].isna()].sample(15))
# Out:
#                               client_msg_id     type         user  \
# 6132                                    NaN  message  U03JZSU0VE0
# 3734   9dfda265-a43f-4ce7-81e4-0b984185737d  message  U036P42C39Q
# 19958                                   NaN  message  U02R21WQJE8
# 16565                                   NaN  message  U0156RC47C1
# 11713                                   NaN  message  U02M2F6F7U4
# 20965                                   NaN  message  U040R9YTD36
# 8504                                    NaN  message          NaN
# 1127                                    NaN  message  U03JXF8CQTC
# 13218  0747B317-BC56-4E5B-AEBB-041D026B3575  message  U03AA7URN3B
# 5113                                    NaN  message  U040G4UTEMU
# 18624                                   NaN  message  U02U272E3K5
# 17636                                   NaN  message  U0351FRV8UX
# 11366                                   NaN  message          NaN
# ...

# %% [markdown]
# Взаимосвязей необнаружено. Пропуски обработать невозможно.

# %% [markdown]
# #### Пропуски в `user`

# %%
print(f'Всего пропусков:', data['user'].isna().sum())
display(data[data['user'].isna()].sample(10)) # Рассмотрим строки пропусков
# Out:
# Всего пропусков: 2890
#       client_msg_id     type user                  ts        latest_reply  \
# 24803           NaN  message  NaN 2022-11-29 06:00:28                 NaT
# 11969           NaN  message  NaN 2022-11-28 07:01:00                 NaT
# 12302           NaN  message  NaN 2022-11-28 07:00:16 2022-12-11 13:24:35
# 25164           NaN  message  NaN 2022-11-28 07:00:17 2022-12-01 10:00:33
# 11506           NaN  message  NaN 2022-11-28 07:00:35                 NaT
# 24022           NaN  message  NaN 2022-12-09 14:01:42                 NaT
# 26028           NaN  message  NaN 2022-12-05 08:05:39                 NaT
# 8421            NaN  message  NaN 2022-11-28 07:00:41 2022-12-11 18:14:18
# 7855            NaN  message  NaN 2022-11-28 07:00:44 2022-12-10 14:52:10
# 8336            NaN  message  NaN 2022-11-28 07:00:53                 NaT
#
#       team           thread_ts      subtype               channel  file_date  \
# ...

# %%
display(data[data['user'].notna()].sample(10)) # Рассмотрим строки data, где нет пропусков.
# Out:
#                               client_msg_id     type         user  \
# 24446                                   NaN  message  U02KVQJHQ5S
# 25555  e465142d-5f01-45da-9dd9-f2cab40abdee  message  U03MTQFUQLB
# 3425   852cff78-929e-4167-a6e9-666e1d40ff5b  message  U02APGPE54P
# 14609  33F556EC-14C8-46C4-8E78-8A7D07208D6A  message  U0469GGN8BX
# 3900   fecf04bc-70de-43d0-b876-7168407de27a  message  U040G4UNQ06
# 25266  5e609df4-59e4-4665-b75e-d024cd531710  message  U03MTQFUQLB
# 805    d4f7714a-4dbb-421b-8245-1c44adc3a44b  message  U034A1B2WBG
# 20141                                   NaN  message  U042WQ0DEKT
# 6382   49ba9318-cd3c-48da-a8f4-b2df937e6708  message  U0185Q2MK19
# 10384                                   NaN  message  U04663J76J2
#
#                        ts latest_reply       team           thread_ts  \
# 24446 2022-12-07 14:39:03          NaT        NaN                 NaT
# 25555 2022-11-28 13:57:00          NaT  TPV9DP0N4 2022-11-28 04:52:34
# ...

# %%
nnull = data[(data['user'].isna())] # проверим на наличие записей в строках и запишем в dataframe.
nnull['subtype'].unique() # выводим уникальные значения столбца subtype.
# Out:
# array(['bot_message'], dtype=object)

# %% [markdown]
# Пропуски в столбце `user` не ошибочны, а являются техническими пропусками при сообщениях от Бота. Оставим пропуски без изменений.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Создадим функцию для построения графиков.

# %%
def plot_mes(x,y, title, xlable, ylable): # описание функции и их переменные. Х-значения по оси Х, Y- значения по оси Y
    unit = data.loc[data[x].notna(), [y, x]] \
        .groupby(y) \
        .agg(['count']) 
    unit.columns = unit.columns.get_level_values(1)
    ax = unit.plot.bar(figsize=(12,6)) 
    plt.title(title)
    plt.xlabel(xlable)
    plt.ylabel(ylable)
    plt.show()

# %% [markdown]
# ### Сообщения.

# %% [markdown]
# Рассмотрим взаимосвязь типов сообщений с количеством постов. Используем подсчет слов медианой, исключив тем самым единичные выбросы.

# %%
(
    data
    .groupby('subtype')
    .agg({'ts': 'count',
          'text_words':'median'})
    .sort_values(by='ts', 
                 ascending=False)
    .rename(columns = {'ts':'count_message', 
                       'text_words':'median_text_word'})
)
# Out:
#                    count_message  median_text_word
# subtype
# post_message               18216              16.0
# channel_leave               3265               5.0
# bot_message                 2890              13.0
# channel_join                2026               5.0
# thread_broadcast             108               9.0
# tombstone                     14               4.0
# channel_unarchive             10               8.0
# channel_purpose                2              15.5
# bot_remove                     1               7.0
# channel_name                   1               8.0

# %%
#код ревьюера
(
    data
    .groupby('subtype')
    .agg({'ts': 'count',
          'text_words':'median'})
    .sort_values(by='ts',
                 ascending=False)
    .rename(columns = {'ts':'count_message',
                       'text_words':'avg_text_word'})
)
# Out:
#                    count_message  avg_text_word
# subtype
# post_message               18216           16.0
# channel_leave               3265            5.0
# bot_message                 2890           13.0
# channel_join                2026            5.0
# thread_broadcast             108            9.0
# tombstone                     14            4.0
# channel_unarchive             10            8.0
# channel_purpose                2           15.5
# bot_remove                     1            7.0
# channel_name                   1            8.0

# %% [markdown]
# Число сообщений пользователей опубликованных всего 18 216 шт. Число пользователей покинувших каналы на 38% больше присоедившихся, что является оттоком пользователей. Число слов в среднем в сообщении от пользователя - 16. От Бота 13 слов, следовательно пользователи пишут в среднем больше ботов.

# %%
plot_mes('client_msg_id','ts_h','Кол-во сообщений в зависимости от часа публикации сообщения','Часы','Кол-во сообщений')

# %% [markdown]
# Чаще всего писали сообщений пользователи в 13:00 часов , реже с 12:00 до 15:00, реже всего в 23:00 и 00:00.

# %% [markdown]
# Рассмотрим зависимость технических сообщений.

# %%
(
    data.query('subtype == "bot_message"')
    .pivot_table(values = 'subtype', index = 'ts_h', aggfunc='count')
    .plot(kind='bar', grid = True ,figsize = (12,5))
);

# %% [markdown]
# Технические сообщения бота выводились в основном в 7-00, очень редко с 8-00 до 20-00, а до 6-00  и после 20-00 Никогда. Возможно с таким диапазоном настроен чат-бот.

# %%
plot_mes('client_msg_id','ts_w','Кол-во сообщений в зависимости от дня недели публикации сообщения','День недели','Кол-во сообщений')

# %% [markdown]
# Чаще сообщения пишут в понедельник и вторник. Реже всего в субботу.
# Возможно это связано с рабочими днями пользователей.

# %%
plot_mes('client_msg_id','ts_mnth','Кол-во сообщений в зависимости от месяца публикации сообщения','месяц','Кол-во сообщений')

# %% [markdown]
# Из графика видно, что сообщений больше публиковали в декабре, меньше всего в октябре, а в январе и феврале не было публикаций вовсе.

# %%
plot_mes('client_msg_id','ts_y','Кол-во сообщений в зависимости от года публикации сообщения','год','Кол-во сообщений')

# %% [markdown]
# Вывод: Сообщения были написаны только в 2022 году, в 2023 году за 2 месяца не было написано ни одного сообщения. Это связано с переходом пользователей в другую систему-messanger

# %%
data[['client_msg_id','profession']] \
    .groupby('profession').agg('count') \
    .sort_values(by='client_msg_id', ascending=False) \
    .plot(title='Количество сообщений в зависимости от профессий', kind='bar');

# %% [markdown]
# Из графика видно, что больше публикаций сообщений было в каналах по профессиям DA и DS, реже DE и DL

# %%
data[['client_msg_id','cohorts']] \
    .groupby('cohorts').agg('count') \
    .sort_values(by='client_msg_id', ascending=False) \
    .plot(title='Количество сообщений в зависимости от когорт', kind='bar');

# %% [markdown]
# Чаще сообщения публиковали в каналах project и exerciser.
# Возможно это связано с спецификой самих каналов. К примеру в канале project в основном все сообщения будут связаны с проектами. Сообщения могут быть как от студентов, которые задают вопросы и от преподавателей, которые дают ответы, но так же вестись обсуждения другими пользователями.

# %% [markdown]
# ### Реакции
#
# Используем функцию для построения однотипных графиков.

# %%
def plot_rat_time(x,y, ttle):
    data[[x,y]] \
    .groupby(y).agg('sum') \
    .plot(title=ttle, kind='bar')

def plot_rat(x,y, ttle):
    data[[x,y]] \
    .groupby(y).agg('count') \
    .sort_values(by=x, ascending=False) \
    .plot(title=ttle, kind='bar')

# %%
plot_rat_time('r_counts','ts_h','Количество реакций в зависимости от часа')
plot_rat_time('r_counts','ts_w','Количество реакций в зависимости от дня недели')
plot_rat_time('r_counts','ts_mnth','Количество реакций в зависимости от месяца')
plot_rat_time('r_counts','ts_y','Количество реакций в зависимости от года')
plot_rat('r_counts','cohorts','Количество реакций в зависимости от канала')
plot_rat('r_counts','profession','Количество реакций в зависимости от профессий')

# %% [markdown]
# Чаще рейтинги ставили на сообщения в 7:00 и 14:00 дня, в понедельник и в декабре.
# Хуже ставили ночью: с 0:00 до 3:00 и в 23:00. По дням недели в субботу,а по месяцам в октябре.
# Число реакций больше в каналах project и exerciser.
# Чаще реации ставят пользватели в группах по профессиям DA И DS.

# %%
#код ревьюера

'''Возьмем один из графиков, например, количество реакций в зависимости от часов.
   Наложим на него другой график - общее количество сообщений по часам
   (и технические, и пользовательские).
'''
#отобразим график количества реакций в зависимости от часа
#код аналогичен коду функции (агрегация через count)
ax1 = data.groupby('ts_h').agg(count=('ts', 'count')).plot(kind='bar',
                                                           figsize=(10, 5),
                                                           color='g',
                                                           alpha=0.4)

#отобразим график количества всех сообщений в зависимости от часа
ax2 = data.groupby('ts_h').agg(reactions=('r_counts', 'count')).plot(kind='bar',
                                                                 figsize=(10, 5),
                                                                 color='r',
                                                                 alpha=0.4,
                                                                 ax=ax1)
plt.title('Сравнение графиков числа реакций и всех публикаций по часам', fontsize=15);

# %%
ax1 = data.groupby('ts_h').agg(count=('ts', 'count')).plot(kind='bar',
                                                           figsize=(10, 5),
                                                           color='g',
                                                           alpha=0.4)

#отобразим график суммы всех сообщений в зависимости от часа.
ax2 = data.groupby('ts_h').agg(reactions=('r_counts', 'sum')).plot(kind='bar',
                                                                 figsize=(10, 5),
                                                                 color='r',
                                                                 alpha=0.4,
                                                                 ax=ax1)
plt.title('Сравнение графиков числа реакций и всех публикаций по часам', fontsize=15);

# %% [markdown]
# ### Лучший Пользователь

# %% [markdown]
# Создадим функцию для однотипных графиков

# %%
def plot_usrs(x,y,ttle,xlable,ylable,agg,x2,y2,ttle2,xlable2,ylable2,agg2):
    a = data[[x,y]] \
        .groupby(y).agg(agg) \
        .sort_values(by=x, ascending=False)
    a = a.head(30)
    ax1 = plt.subplot(1, 2, 1)
    a.plot.bar(figsize=(12,6),grid=True,title = ttle,ax=ax1)
    
    b = data[[x2,y2]] \
        .groupby(y2).agg(agg2) \
        .sort_values(by=x2, ascending=False)
    b = b.head(30)
    ax2 = plt.subplot(1, 2, 2,sharey=ax1)
    b.plot.bar(figsize=(12,6),grid=True,title = ttle2,ax=ax2)

# %%
plot_usrs('client_msg_id','user', 'Топ пользователей по количеству постов', 'пользователи','количество постов', 'count','r_counts','user','Топ пользователей по количеству реакций','пользователи','количество реакций','count')

# %% [markdown]
# Лучший пользователь по количеству постов: U03F5HNG351
# Лучший пользователь по количеству реакций: U02KVQJHQ5S

# %%
plot_usrs('text_len','user','Топ пользователей по длине предложений','пользователи','плина предложений','median','text_words','user','Топ пользователей по количеству слов в сообщении','пользователи','число слов','median');

# %% [markdown]
# Лучший пользователь по длине предложений: U03TNBHUG7L
# Лучший пользователь по количеству слов в сообщении: U02F0NAKLN5

# %%
(
    data[['attachments','user']] \
        .groupby('user').agg('sum') \
        .sort_values(by='attachments', ascending=False)
        .head(30)
        .plot.bar(figsize=(10,5),grid=True, title = 'Топ пользователей по числу вложений')
);

# %% [markdown]
# Лучшие пользователи:
# - по количеству постов UO3F5HNG351
# - по количеству реакций UO2KVQJHQ5S
# - по количеству вложений U01922M27K7 и U04548A5P1N
# - по длине предложений U03TNBHUG7L
# - по количеству слов в сообщении U02F0NAKLN5
#
# Рассмотрим этих пользователей подробнее.

# %%
display(
  data[['client_msg_id','r_counts','attachments','user','text_len','text_words']]
    .query('user in ["U03F5HNG351","U02KVQJHQ5S","U01922M27K7", "U04548A5P1N","U03TNBHUG7L","U02F0NAKLN5" ]')
    .groupby('user')
    .agg({'client_msg_id':'count',
          'r_counts':'count',
          'attachments':'sum',
          'text_len':'median',
          'text_words':'median' })
    .sort_values(by='attachments', ascending=False)
)
# Out:
#              client_msg_id  r_counts  attachments  text_len  text_words
# user
# U01922M27K7             34        34           11     156.0        23.5
# U04548A5P1N             12        12           11     391.0        55.0
# U02F0NAKLN5              1         1            0    1400.0       251.0
# U02KVQJHQ5S              0       514            0      37.0         5.0
# U03F5HNG351            252       252            0     144.5        22.0
# U03TNBHUG7L              1         1            0    1608.0       205.0

# %% [markdown]
# Пользователь U03F5HNG351, написавший больше всех постов не прикреплял ниединого вложения. Сплошной текст в среднем по 22 слова за пост. Вероятнее всего реакции он ставил себе на посты.
# Пользователь UO2KVQJHQ5S, поставивший больше всего реакций не написал ни одного поста. Оставил комментарии к постам, всего 5 слов. Вероятнее всего это ученик.
# Пользователь U01922M27K7, больше всего прикрепивший вложения опубликовал всего 34 поста и написал всего всреднем 23 слова за пост.
# Пользователь U04548A5P1N, больше всего прикрепивший вложения опубликовал всего 12 постов, но зато написал в среднем 55 слов.

# %% [markdown]
# Можно выделить графики:
# 1. График пользователей по количеству вложений. Видно, что мало используются вложений при написании сообщений. Отсутствие визуального сопровождения постов пагубно влияет на понимание сути и может влиять на малое количество реакций.
# 2. График пользователей по количеству слов в сообщении. Обычно большой текст в сообщениях плохо воспринимается пользователями.

# %% [markdown]
# ### Приток и отток пользователей

# %% [markdown]
# Создадим функцию для однотипных графиков.

# %%
def plt_subtipe (x,y,title_1,title_2,status_1, status_2,xlabel):
    a = data.loc[data['subtype'] == status_1]
    a = a.groupby(x) \
         .agg({y:'count'})
    b = data.loc[data['subtype'] == status_2]
    b = b.groupby(x) \
         .agg({y:'count'})
# первый график
    ax1 = plt.subplot(1, 2, 1)
    a.plot.bar(figsize=(12,6),grid=True, ax=ax1)
    plt.legend()
    plt.xlabel(xlabel)
    plt.title(title_1)
# второй график
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    b.plot.bar(figsize=(12,6),grid=True, ax=ax2)
    plt.xlabel(xlabel)
    plt.title(title_2)

# %%
plt_subtipe('ts_h','user','кол-во пользователей присоединилось (по часам)','кол-во пользователей покинуло (по часам)','channel_join','channel_leave','часы')

# %%
plt_subtipe('ts_w','user','кол-во пользователей присоединилось(по дням недели)','кол-во пользователей покинуло (по дням недели)','channel_join','channel_leave','дни недели')

# %%
plt_subtipe('ts_mnth','user','кол-во пользователей присоединилось(по месяцам)','кол-во пользователей покинуло (по месяцам)','channel_join','channel_leave','месяц')

# %% [markdown]
# Больше пришло пользователей в чаты по часам в 9:00 и 14:00, по дням недели - в понедельник, по месяцам в декабре.
# Меньше всего пришло пользователей по времени с 20:00 до 4:00, по дням недели - в воскресенье, по месяцам в январе.
#
# Больше покинуло пользователей чаты по часам в 9:00 и 14:00, по дням недели - в понедельник, по месяцам в декабре.
# Меньше всего пришло пользователей по времени с 20:00 до 4:00, по дням недели - в субботу, по месяцам в январе.
#
# Покидает число пользователей больше, чем присоединяются новые. Это явный отток пользователей.
# В основном действия совершаются в один и тот же промежуток времени. Данной динамикой можно воспользоваться для удержания пользователей.

# %%
# график пришедших в канал пользователей
ax1 = data.query('subtype == "channel_join"') \
        .groupby('cohorts') \
        .agg(join =('user', 'count')) \
        .plot(kind='bar', figsize=(10, 5), color='darkblue', alpha=0.4)

# график покинувших в канал пользователей
ax2 = data.query('subtype == "channel_leave"') \
        .groupby('cohorts').agg(leave =('user', 'count')) \
        .plot(kind='bar',figsize=(10, 5),color='lime',alpha=0.4,ax=ax1)
plt.title('Сравнение пришедших и покинутых пользователей в каналах', fontsize=15);

# %% [markdown]
# По каналам так же видно, что число пользователей покинувших каналы больше, чем число пришедших.

# %%
plt_subtipe('profession','user','кол-во пользователей пришло (по профессии)','кол-во пользователей покинуло(по профессии)', 'channel_join','channel_leave','профессии')

# %% [markdown]
# Аналогичная картина и на графиках по профессиям. Число покинувших пользователей каналы больше, чем присоединившихся.

# %% [markdown]
# ## Общий вывод:

# %% [markdown]
# Предобработка данных:
# На этапах предобработки были выявлены пропуски.
# Причиной появления пропусков может быть техническая ошибка.
#
# Были созданы дополнительные столбцы для построения графиков для дальнейшего анализа особенностей и зависимостей.
#
# Исследование данных и зависимостей:
#
# Были построены графики для понимания взаимосвязей.
#
# Факторы влияния на отток пользователей:
# Факторы могут быть различные: не получение обратной связи на пост, невозможность оставлять комментарии, отсутствие мотивации, нарушение правил и т.д.
#
# Построив графики была выявлена закономерность:
# - Пользователи смотрят каналы с утра, в начале недели.
# - Покидают каналы так же с утра, в начале недели.
# - Отток пользователей больше притока.
# - В основном действия совершаются в один и тот же промежуток времени. Данной динамикой можно воспользоваться для удержания пользователей.
# - Основная масса "публикуемых" пользователей не получает большого количества реакций.
# - Мало используются при написании сообщений вложений. Отсутствие визуального сопровождения постов пагубно влияет на понимание сути и может пагубно влиять на количество реакций.
# - Большой текст в сообщениях плохо воспринимается пользователями.
#
# Резюмируя можно сказать:
# Цели выполнены, выявили зависимости и особенности.
#
# Рекомендации:
# 1. Выполнять действия ориентированные на привлечение и удержание пользователей.
# 2. Обратить внимание на периоды публикации важных и интересных сообщений.
